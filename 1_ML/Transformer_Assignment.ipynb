# %% [markdown]
# #ENGR 8990 - Deep Learning & Engineering Applications
# ## Assignment 4 - Transformer for Sentiment Classification
# Assignment: Code a transformer model for sentiment classification.
#
# 1.   Construct a transformer encoder (you could use the one in NB13) as the backbone and add a linear classifier for sentiment classification using the IMDB dataset (note: the vocab for IMDB is different from the NMT dataset used in NB13).
#
# 2.   Train the model and display the proggess showing both training and validation metrics.
#
# 2.   Evaluate the trained model on the test dataset.

# %%
# !pip install d2l==0.17.0
# Out:
# Requirement already satisfied: d2l==0.17.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (0.17.0)
# Requirement already satisfied: jupyter in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from d2l==0.17.0) (1.0.0)
# Requirement already satisfied: numpy in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from d2l==0.17.0) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from d2l==0.17.0) (3.8.3)
# Requirement already satisfied: requests in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from d2l==0.17.0) (2.31.0)
# Requirement already satisfied: pandas in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from d2l==0.17.0) (2.2.1)
# Requirement already satisfied: notebook in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter->d2l==0.17.0) (7.1.2)
# Requirement already satisfied: qtconsole in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter->d2l==0.17.0) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter->d2l==0.17.0) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter->d2l==0.17.0) (7.16.3)
# Requirement already satisfied: ipykernel in c:\users\alvee\appdata\roaming\python\python311\site-packages (from jupyter->d2l==0.17.0) (6.29.4)
# Requirement already satisfied: ipywidgets in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter->d2l==0.17.0) (8.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->d2l==0.17.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->d2l==0.17.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->d2l==0.17.0) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->d2l==0.17.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from matplotlib->d2l==0.17.0) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->d2l==0.17.0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->d2l==0.17.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from matplotlib->d2l==0.17.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from pandas->d2l==0.17.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from pandas->d2l==0.17.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from requests->d2l==0.17.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from requests->d2l==0.17.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from requests->d2l==0.17.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from requests->d2l==0.17.0) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->d2l==0.17.0) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (8.23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (1.6.0)
# Requirement already satisfied: psutil in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->d2l==0.17.0) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->jupyter->d2l==0.17.0) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->jupyter->d2l==0.17.0) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->d2l==0.17.0) (3.0.43)
# Requirement already satisfied: pygments in c:\users\alvee\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->d2l==0.17.0) (2.17.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (5.10.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbconvert->jupyter->d2l==0.17.0) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter->d2l==0.17.0) (2.13.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter->d2l==0.17.0) (2.25.4)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter->d2l==0.17.0) (4.1.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from notebook->jupyter->d2l==0.17.0) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from qtconsole->jupyter->d2l==0.17.0) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->d2l==0.17.0) (0.5.1)
# Requirement already satisfied: decorator in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (4.10.0)
# Requirement already satisfied: colorama in c:\users\alvee\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->d2l==0.17.0) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->d2l==0.17.0) (306)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (4.3.0)
# Requirement already satisfied: argon2-cffi in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (0.5.3)
# Requirement already satisfied: overrides in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (7.7.0)
# Requirement already satisfied: prometheus-client in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (0.20.0)
# Requirement already satisfied: pywinpty in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (0.18.1)
# Requirement already satisfied: websocket-client in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->d2l==0.17.0) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->d2l==0.17.0) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter->d2l==0.17.0) (2.2.4)
# Requirement already satisfied: babel>=2.10 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (0.9.24)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (4.21.1)
# Requirement already satisfied: fastjsonschema in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->d2l==0.17.0) (2.19.1)
# Requirement already satisfied: wcwidth in c:\users\alvee\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->d2l==0.17.0) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->d2l==0.17.0) (2.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->d2l==0.17.0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter->d2l==0.17.0) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->d2l==0.17.0) (0.18.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (0.1.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alvee\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\alvee\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->d2l==0.17.0) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (2.4)
# Requirement already satisfied: uri-template in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\alvee\appdata\local\programs\python\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->d2l==0.17.0) (2.9.0.20240316)

# %%
import torch 
from torch import nn
from d2l import torch as d2l
import math
import torch.optim as optim

# %%
batch_size = 64
train_iter, test_iter, vocab = d2l.load_data_imdb(batch_size)

# %%
len(train_iter), len(test_iter)
# Out:
# (391, 391)

# %%
print("The length of the vocab is", len(vocab))
# Out:
# The length of the vocab is 49346

# %%
for batch in train_iter:
  print (batch[0][0])
  # print (batch[1])
  break
# Out:
# tensor([   48,    20,     6,   131,    32,    36,    82,  9020,  1356,     2,
#         10607, 22968, 12030,    49,    25,   367,    10,   432,   143,    48,
#            20,   702,    35,     2,  6280,     4,  2909, 18748, 11110, 12638,
#            15,  5274, 26051,  4223,     0,     8,    97,    10,     6, 30218,
#           127,   209,   129,     3,    43,    80,  1164,  1582,  9167,    38,
#           207,    71, 12150,    15, 14452,    52,  8852,     3,    32,     0,
#          2314,  9829,  4120,    27,    35,    43,  1271,    42,    25,    70,
#            34,   428,  1037,    35,     0,  9167,    38,   401,    96,    43,
#          2484,     7,     1,  1151,  2182,     3,    75,    26,  2259,   239,
#           109,   537,    24,   220,     3,  8258,   257,     6,    31,     4,
#             1,    80,  1032,  3686,    44,   960,   122,   839,    78,    34,
#            49,    24,   199,     4,  9167,    14,   137,     2,  3809,  5530,
#             0,   257,     6,  2185,   831,     1,  2923,    20, 32951,     4,
#          2031,  9167,     6,     2,   164,   364,    19,     1,   168,   911,
#            14,  9527,     0, 20615,     0,  6330, 21372,  6078, 36151,     3,
#             2,   163,  2899,     7,     9,    68,   102,   179,     5,    26,
#             0,    68,    58,   405,     1,   123, 19128,   257,    38,    47,
#            69,  4968,     1,  1409,     4,    43, 17527,     3,     4,     1,
#         14940, 32193,    12, 10316,    41, 30223,     6,   432,    70,     1,
#           668,     1,  5722,     1,  3477,     1, 13753,     8,   102,    74,
#          1523,     4,   162,    10,   734,    12,  9036,    82,   648,    82,
#             8,   117,     1,   156,   110,    37,    21,    36,  1247,   201,
#             1,  4754,  4590,    30, 18955,  2051,     8,  9446,     1,  3275,
#             5,    66,   579,    50,  8458,  2276,  3704,     6,     0,     8,
#           206,     1,     0, 21690,   790, 23565,    17,     8,   185,    84,
#            44,   766,    37,    21,  2380,     0,     0,   254,     6,     9,
#           268,     0,    55,   260,   432,     3,    91,  2096,    83,     0,
#           106,    12, 40182,     7,     9,   272,    13,     2, 27002,  2595,
#             3,    37,  5922,     3,  4153,    41,    31,  2978,    18,  7735,
#           269,  3792,  2273,     3,     0,    28,    13,     2,  6997,   197,
#             4,     1,   272,     3,    28,    13,  9457,     5,     3,  5922,
#            16,    22,   876,     3, 32952,   144,   412,     5,    26,     2,
#           184, 39732,  1860,   182, 45573,  3810,    12,     0,  2469,   269,
#         11452,     2,     0,    68,    13,     1, 15707,     9,  1520,     1,
#           272,   388,     3,    13,     2,  2820,   708,     4,    50,     2,
#          1733,  2896,     3,   452,  4176,   134, 17525,     5,  1146,   257,
#            13,  3107,     4,     1,  6465,    68,    57,  2476,    17,    68,
#           154,   397,    11,  7671,    34,    68,  1372,  2716, 16064, 24384,
#           651,    14,  4446,     7,    54,  3371,    14,  3704,     0,  1372,
#         19584,     1, 27159,   111,    68,   354,  1214,   154,    24,   429,
#           332,   109,     8,    13,     0,    55,  3237,   130, 24888,    91,
#             0,   255,   181,     1,   327,     9,    68,    57,    71,     1,
#           604,     4,   198,   295,    34,   124,   579,    14,    68,  4059,
#             3,   181,    43,   111,   205,     1,    79,   460,  4951,    50,
#            57,  3052,   257,    13,  5482,  1906,     0,     3,    46, 15594,
#           254,     2,    94,     0,   106,    12,   170,   154,   166,    35,
#          7807,   256,   294,    78,    68,   412,    35,     2,   222,     4,
#             2,     0,    34,   269,    58,    14, 13651,     3,    14,     7,
#          1451,     4,   923,    14,    68,   431,   537,     5,  4122,   257,
#            85,   352,   537,    41,   703,     3,   110,    37,    57,  1002])

# %% [markdown]
# # Code starts here

# %% [markdown]
# ### Define the Transformer encoder as the backbone

# %%
class PositionWiseFFN(nn.Module):
    """Positionwise feed-forward network."""
    def __init__(self, ffn_num_input, ffn_num_hiddens, ffn_num_outputs,
                 **kwargs):
        super(PositionWiseFFN, self).__init__(**kwargs)
        self.dense1 = nn.Linear(ffn_num_input, ffn_num_hiddens)
        self.relu = nn.ReLU()
        self.dense2 = nn.Linear(ffn_num_hiddens, ffn_num_outputs)

    def forward(self, X):
        return self.dense2(self.relu(self.dense1(X)))
    
## Residual Connection and Layer Normalization

ln = nn.LayerNorm(2)
bn = nn.BatchNorm1d(2)

class AddNorm(nn.Module):
    """Residual connection followed by layer normalization."""
    def __init__(self, normalized_shape, dropout, **kwargs):
        super(AddNorm, self).__init__(**kwargs)
        self.dropout = nn.Dropout(dropout)
        self.ln = nn.LayerNorm(normalized_shape)

    def forward(self, X, Y):
        # print("test add")
        return self.ln(self.dropout(Y) + X)
    



## Encoder

class EncoderBlock(nn.Module):
    """Transformer encoder block."""
    def __init__(self, key_size, query_size, value_size, num_hiddens,
                 norm_shape, ffn_num_input, ffn_num_hiddens, num_heads,
                 dropout, use_bias=False, **kwargs):
        super(EncoderBlock, self).__init__(**kwargs)
        self.attention = d2l.MultiHeadAttention(key_size, query_size,
                                                value_size, num_hiddens,
                                                num_heads, dropout, use_bias)
        self.addnorm1 = AddNorm(norm_shape, dropout)
        self.ffn = PositionWiseFFN(ffn_num_input, ffn_num_hiddens,
                                   num_hiddens)
        self.addnorm2 = AddNorm(norm_shape, dropout)

    def forward(self, X, valid_lens):
        Y = self.addnorm1(X, self.attention(X, X, X, valid_lens))
        # print('test')
        return self.addnorm2(Y, self.ffn(Y))
    



class TransformerEncoder(d2l.Encoder):
    """Transformer encoder."""
    def __init__(self, vocab_size, key_size, query_size, value_size,
                 num_hiddens, norm_shape, ffn_num_input, ffn_num_hiddens,
                 num_heads, num_layers, dropout, use_bias=False, **kwargs):
        super(TransformerEncoder, self).__init__(**kwargs)
        self.num_hiddens = num_hiddens
        self.embedding = nn.Embedding(vocab_size, num_hiddens)
        self.pos_encoding = d2l.PositionalEncoding(num_hiddens, dropout)
        self.blks = nn.Sequential()
        for i in range(num_layers):
            self.blks.add_module(
                "block" + str(i),
                EncoderBlock(key_size, query_size, value_size, num_hiddens,
                             norm_shape, ffn_num_input, ffn_num_hiddens,
                             num_heads, dropout, use_bias))

    def forward(self, X, valid_lens, *args):
        # Since positional encoding values are between -1 and 1, the embedding
        # values are multiplied by the square root of the embedding dimension
        # to rescale before they are summed up
        X = self.pos_encoding(self.embedding(X) * math.sqrt(self.num_hiddens))
        self.attention_weights = [None] * len(self.blks)
        for i, blk in enumerate(self.blks):
            X = blk(X, valid_lens)
            self.attention_weights[
                i] = blk.attention.attention.attention_weights
        # print('encoder_passed')
        return X

# %% [markdown]
# ### Linear Classifier

# %%
class SentimentClassifier(nn.Module):
    """Linear classifier for sentiment classification."""
    def __init__(self, num_hiddens, num_outputs):
        super(SentimentClassifier, self).__init__()
        self.dense = nn.Linear(num_hiddens, num_outputs)

    def forward(self, X):
        # X shape: (batch_size, seq_length, num_hiddens)
        # Average pooling over the sequence length
        X = X.mean(dim=1)
        # Apply the linear layer
        return self.dense(X)

# %% [markdown]
# ### Add the linear classifier on top of the Transformer encoder

# %%
num_hiddens, num_layers, dropout, batch_size = 32, 2, 0.1, 64
lr, num_epochs, device = 0.005, 10, d2l.try_gpu()
ffn_num_input, ffn_num_hiddens, num_heads = 32, 64, 2
key_size, query_size, value_size = 32, 32, 32
norm_shape = [32]
num_outputs = 2

encoder = TransformerEncoder(len(vocab), key_size, query_size, value_size,
                             num_hiddens, norm_shape, ffn_num_input,
                             ffn_num_hiddens, num_heads, num_layers, dropout)

classifier = SentimentClassifier(num_hiddens, num_outputs)

net = nn.Sequential(encoder, classifier)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Move the model to the appropriate device
net.to(device)
# Out:
# Sequential(
#   (0): TransformerEncoder(
#     (embedding): Embedding(49346, 32)
#     (pos_encoding): PositionalEncoding(
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (blks): Sequential(
#       (block0): EncoderBlock(
#         (attention): MultiHeadAttention(
#           (attention): DotProductAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (W_q): Linear(in_features=32, out_features=32, bias=False)
#           (W_k): Linear(in_features=32, out_features=32, bias=False)
#           (W_v): Linear(in_features=32, out_features=32, bias=False)
#           (W_o): Linear(in_features=32, out_features=32, bias=False)
#         )
#         (addnorm1): AddNorm(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (ln): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         )
#         (ffn): PositionWiseFFN(
#           (dense1): Linear(in_features=32, out_features=64, bias=True)
#           (relu): ReLU()
#           (dense2): Linear(in_features=64, out_features=32, bias=True)
#         )
#         (addnorm2): AddNorm(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (ln): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (block1): EncoderBlock(
#         (attention): MultiHeadAttention(
#           (attention): DotProductAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (W_q): Linear(in_features=32, out_features=32, bias=False)
#           (W_k): Linear(in_features=32, out_features=32, bias=False)
#           (W_v): Linear(in_features=32, out_features=32, bias=False)
#           (W_o): Linear(in_features=32, out_features=32, bias=False)
#         )
#         (addnorm1): AddNorm(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (ln): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         )
#         (ffn): PositionWiseFFN(
#           (dense1): Linear(in_features=32, out_features=64, bias=True)
#           (relu): ReLU()
#           (dense2): Linear(in_features=64, out_features=32, bias=True)
#         )
#         (addnorm2): AddNorm(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (ln): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (1): SentimentClassifier(
#     (dense): Linear(in_features=32, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Training

# %%
# Define loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.005)

# %%
torch.cuda.empty_cache()

# %%
# Training loop
num_epochs = 10
for epoch in range(num_epochs):
    net.train()
    for batch_idx, (data, label) in enumerate(train_iter):
        # Move data to the appropriate device
        # Calculate valid_lens for each batch
        max_len = 100  # Assuming max_len is the maximum sequence length you choose
        actual_lens = [min(len(batch), max_len) for batch in data]
        valid_lens = torch.tensor(actual_lens).to(device)

        data, valid_lens, label = data.to(device), valid_lens.to(device), label.to(device)

        optimizer.zero_grad()
        output_tr = net[0](data,valid_lens)
        # print(output_tr.shape)
        output = net[1](output_tr)
        loss = loss_fn(output, label)
        loss.backward()
        optimizer.step()
        
        # Print training statistics
        if batch_idx % 100 == 0:
            print('Epoch {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_iter.dataset),
                100. * batch_idx / len(train_iter), loss.item()))
# Out:
# Epoch 0 [0/25000 (0%)]	Loss: 0.628006
# Epoch 0 [6400/25000 (26%)]	Loss: 0.558304
# Epoch 0 [12800/25000 (51%)]	Loss: 0.496133
# Epoch 0 [19200/25000 (77%)]	Loss: 0.520266
# Epoch 1 [0/25000 (0%)]	Loss: 0.385856
# Epoch 1 [6400/25000 (26%)]	Loss: 0.368676
# Epoch 1 [12800/25000 (51%)]	Loss: 0.386535
# Epoch 1 [19200/25000 (77%)]	Loss: 0.442894
# Epoch 2 [0/25000 (0%)]	Loss: 0.349800
# Epoch 2 [6400/25000 (26%)]	Loss: 0.329548
# Epoch 2 [12800/25000 (51%)]	Loss: 0.400390
# Epoch 2 [19200/25000 (77%)]	Loss: 0.318013
# Epoch 3 [0/25000 (0%)]	Loss: 0.264718
# Epoch 3 [6400/25000 (26%)]	Loss: 0.546205
# Epoch 3 [12800/25000 (51%)]	Loss: 0.222603
# Epoch 3 [19200/25000 (77%)]	Loss: 0.254005
# Epoch 4 [0/25000 (0%)]	Loss: 0.299474
# Epoch 4 [6400/25000 (26%)]	Loss: 0.289582
# Epoch 4 [12800/25000 (51%)]	Loss: 0.239002
# Epoch 4 [19200/25000 (77%)]	Loss: 0.242855
# Epoch 5 [0/25000 (0%)]	Loss: 0.173560
# Epoch 5 [6400/25000 (26%)]	Loss: 0.163944
# Epoch 5 [12800/25000 (51%)]	Loss: 0.190923
# Epoch 5 [19200/25000 (77%)]	Loss: 0.278744
# Epoch 6 [0/25000 (0%)]	Loss: 0.216956
# Epoch 6 [6400/25000 (26%)]	Loss: 0.140919
# Epoch 6 [12800/25000 (51%)]	Loss: 0.066958
# Epoch 6 [19200/25000 (77%)]	Loss: 0.139260
# Epoch 7 [0/25000 (0%)]	Loss: 0.250667
# Epoch 7 [6400/25000 (26%)]	Loss: 0.067114
# Epoch 7 [12800/25000 (51%)]	Loss: 0.221727
# Epoch 7 [19200/25000 (77%)]	Loss: 0.136913
# Epoch 8 [0/25000 (0%)]	Loss: 0.152830
# Epoch 8 [6400/25000 (26%)]	Loss: 0.173977
# Epoch 8 [12800/25000 (51%)]	Loss: 0.051378
# Epoch 8 [19200/25000 (77%)]	Loss: 0.135902
# Epoch 9 [0/25000 (0%)]	Loss: 0.125827
# Epoch 9 [6400/25000 (26%)]	Loss: 0.119303
# Epoch 9 [12800/25000 (51%)]	Loss: 0.151410
# Epoch 9 [19200/25000 (77%)]	Loss: 0.081399

# %%
# Validation

net.eval()  # Set the model to evaluation mode
total_correct = 0
total_samples = 0
with torch.no_grad():  # Disable gradient computation during validation
    for data, label in test_iter:
        # Move data to the appropriate device
        data, label = data.to(device), label.to(device)

        # Calculate valid_lens for each batch
        max_len = 100  # Assuming max_len is the maximum sequence length you choose
        actual_lens = [min(len(batch), max_len) for batch in data]
        valid_lens = torch.tensor(actual_lens).to(device)

        # Forward pass
        output_tr = net[0](data, valid_lens)
        output = net[1](output_tr)
        loss = loss_fn(output, label)

        # Compute predictions
        _, predicted = torch.max(output, 1)

        # Update total samples and total correct predictions
        total_samples += label.size(0)
        total_correct += (predicted == label).sum().item()

# Compute accuracy
accuracy = total_correct / total_samples
print('Validation Accuracy: {:.2f}%'.format(accuracy * 100))
# Out:
# Validation Accuracy: 80.00%
